# %%
# %%writefile myfile.txt
#
# test1
# Out:
# Writing myfile.txt

# %%
myFile = open("myfile.txt")

# %%
type(myFile)
# Out:
# _io.TextIOWrapper

# %%
myFile.read()
# Out:
# '\ntest1\n'

# %%
myFile.read()
# Out:
# ''

# %%
myFile.seek(0)
# Out:
# 0

# %%
myFile.read()
# Out:
# '\ntest1\n'

# %%
myFile.close()

# %%
with open("myfile.txt") as myFile:
    myContent = myFile.read()

# %%
myContent
# Out:
# '\ntest1\n'

# %%
with open("myfile.txt", mode = "w") as newMyFile:
    newMyFile.write("test 2")

# %%
newMyFile
# Out:
# <_io.TextIOWrapper name='myfile.txt' mode='w' encoding='UTF-8'>

# %%
with open("myfile.txt", mode="r") as myFile2:
    myContent = myFile2.read()

# %%
myContent
# Out:
# 'test 2'

# %%
with open("myfile.txt", mode="a") as myFile3:
    myFile3.write("test 3")

# %%
with open("myfile.txt", mode="r") as myFile4:
    myContent = myFile4.read()

# %%
myContent
# Out:
# 'test 2test 3'
