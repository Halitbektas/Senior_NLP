# %%
age = input("enter your age:")
# Out:
# enter your age: atil

# %%
int(age) * 2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 int(age) * 2
#
# ValueError: invalid literal for int() with base 10: 'atil'

# %%
try:
    myAge = int(input("enter your age:"))
    print(myAge * 2)
except ValueError:
    print(ValueError)
# Out:
# enter your age: 35
# 70
