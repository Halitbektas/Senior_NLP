# %% [markdown]
# # Variables

# %%
900 / 7
# Out:
# 128.57142857142858

# %%
5 * 5 * 5
# Out:
# 125

# %%
5 ** 3
# Out:
# 125

# %%
age = 50

# %%
pi = 3.14

# %%
type(pi)
# Out:
# float

# %%
type(age)
# Out:
# int

# %%
type(40 / 4)
# Out:
# float

# %%
4.4 - 2
# Out:
# 2.4000000000000004

# %%
"hello world"
# Out:
# 'hello world'

# %%
print("hello world")
# Out:
# hello world

# %%
name = "halit"

# %%
type(name)
# Out:
# str

# %%
name = "Halit Bektaş"

# %%
name.capitalize()
# Out:
# 'Halit bektaş'

# %%
help(name.capitalize)
# Out:
# Help on built-in function capitalize:
#
# capitalize() method of builtins.str instance
#     Return a capitalized version of the string.
#
#     More specifically, make the first character have upper case and the rest lower
#     case.

# %%
len(name)
# Out:
# 12

# %% [markdown]
# # İndex

# %%
myString = "Hello Python"

# %%
myString[10]
# Out:
# 'o'

# %%
myString[-1]
# Out:
# 'n'

# %%
barcode = "ABCDE125643"

# %%
barcode[::]
# Out:
# 'ABCDE125643'

# %%
barcode[3::]
# Out:
# 'DE125643'

# %%
barcode[::-1]
# Out:
# '346521EDCBA'

# %% [markdown]
# # Lists

# %%
myString
# Out:
# 'Hello Python'

# %%
myString[0]
# Out:
# 'H'

# %%
#myString[0] = "a"

# %%
myLists = [10,20,30,40,50]

# %%
myLists.append(80)

# %%
myLists.index(40)
# Out:
# 3

# %%
x = input("enter x:")
# Out:
# enter x: 20

# %%
int(x)
# Out:
# 20

# %%
type(x)
# Out:
# str

# %%
mixList = ["halit",3,3.14]

# %%
type(mixList)
# Out:
# list

# %%
# nestedList

# %%
myNestedList = [10,20,30,"halit",[1,2,3]]

# %% [markdown]
# # Dictionary

# %%
fitnessDictionary = {"banana":100,"apple":150}

# %%
type(fitnessDictionary)
# Out:
# dict

# %%
type(fitnessDictionary.values())
# Out:
# dict_values

# %%
list(fitnessDictionary.values())
# Out:
# [100, 150]

# %%
fitnessDictionary.get("apple")
# Out:
# 150

# %%
last_dictionary = {"k1":10,"k2":[10,20,30],"k3":"string","k4":{"a":100,"b":200}}

# %%
last_dictionary["k4"]["b"]
# Out:
# 200

# %%
last_dictionary["k2"][2]
# Out:
# 30

# %% [markdown]
# # Sets

# %%
#unigue elements

# %%
mySet = {10,20,30,40}

# %%
mySet.add(10)

# %%
mySet.add(50)

# %%
mySet
# Out:
# {10, 20, 30, 40, 50}

# %%
mySet2 = {40,50,60,70}

# %%
mySet.union(mySet2)
# Out:
# {10, 20, 30, 40, 50, 60, 70}

# %%
mySet.intersection(mySet2)
# Out:
# {40, 50}

# %%
emptySet = set()

# %%
emptyList = list()

# %%
emptyDict = dict()

# %% [markdown]
# # Tuple

# %%
myList = [10,20,"a"]

# %%
myTuple = (10,20,"a")

# %%
type(myTuple)
# Out:
# tuple

# %%
myTuple.count(10)
# Out:
# 1

# %%
myTuple.index(10)
# Out:
# 0

# %%
#değiştirilemiyorlar

# %% [markdown]
# # Bool
