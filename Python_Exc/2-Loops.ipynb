# %%
myList = [10,20,30,40]

# %%
for num in myList:
    print(num)
# Out:
# 10
# 20
# 30
# 40

# %%
newList = [("a","b"),("c","d"),("e","f")]

# %%
for (x,y) in newList:
    print(x)
# Out:
# a
# c
# e

# %%
myDict = {"k1":100,"k2":200}

# %%
for i in myDict.items():
    print(i)
# Out:
# ('k1', 100)
# ('k2', 200)

# %%
for element in enumerate(myList):
    print(element)
# Out:
# (0, 10)
# (1, 20)
# (2, 30)
# (3, 40)

# %%
from random import randint

# %%
randint(0,100)
# Out:
# 3
