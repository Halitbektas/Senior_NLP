# %%
import numpy as np

# %%
first_array = np.array([[10,20],[30,40]])
second_array = np.array([[1,2],[3,4]])

# %%
first_array + second_array
# Out:
# array([[11, 22],
#        [33, 44]])

# %%
first_array * second_array
# Out:
# array([[ 10,  40],
#        [ 90, 160]])

# %%
first_matrix = np.array([[10,20,30]])

# %%
first_matrix.shape
# Out:
# (1, 3)

# %%
second_matrix = np.array([[10],[20],[30]])

# %%
second_matrix.shape
# Out:
# (3, 1)

# %%
first_matrix.dot(second_matrix).shape
# Out:
# (1, 1)

# %%
new_array = np.random.randint(1,100,20)

# %%
new_array
# Out:
# array([96, 22, 27, 81, 60, 49, 89, 12, 62, 46, 46, 63, 21, 42, 42, 49, 61,
#        62, 21, 31])

# %%
new_array > 25
# Out:
# array([ True, False,  True,  True,  True,  True,  True, False,  True,
#         True,  True,  True, False,  True,  True,  True,  True,  True,
#        False,  True])

# %%
new_array[new_array > 25]
# Out:
# array([96, 27, 81, 60, 49, 89, 62, 46, 46, 63, 42, 42, 49, 61, 62, 31])

# %%
matrix_array = np.array([[10,20],[20,30],[30,40]])

# %%
matrix_array.transpose()
# Out:
# array([[10, 20, 30],
#        [20, 30, 40]])

# %%
random_array = np.random.random((6,1))

# %%
random_array
# Out:
# array([[0.90034574],
#        [0.28165599],
#        [0.93478883],
#        [0.87230467],
#        [0.13228261],
#        [0.36584084]])

# %%
random_array.reshape(2,3)
# Out:
# array([[0.90034574, 0.28165599, 0.93478883],
#        [0.87230467, 0.13228261, 0.36584084]])

# %%
data = np.array([10,12,13,15,18,25,100,105])

# %%
mean = np.mean(data)

# %%
mean
# Out:
# np.float64(37.25)

# %%
data.sum() / len(data)
# Out:
# np.float64(37.25)

# %%
std = np.std(data)

# %%
std
# Out:
# np.float64(37.9333296719389)

# %%
z_scores = (data - mean) / std

# %%
z_scores
# Out:
# array([-0.71836562, -0.66564154, -0.6392795 , -0.58655542, -0.50746929,
#        -0.322935  ,  1.65421809,  1.78602829])

# %%
z_scores[z_scores>1]
# Out:
# array([1.65421809, 1.78602829])
