# %%
import pandas as pd
import numpy as np

# %%
grade = {
    "Atil":50,
    "James":60,
    "Lars":30
}

# %%
pd.Series(grade)
# Out:
# Atil     50
# James    60
# Lars     30
# dtype: int64

# %%
names = ["halit","nisa","enes"]

# %%
grades = [50,20,60]

# %%
pd.Series(grades,names)
# Out:
# halit    50
# nisa     20
# enes     60
# dtype: int64

# %%
numpy_array = np.array([50,40,70,30])

# %%
pd.Series(numpy_array)
# Out:
# 0    50
# 1    40
# 2    70
# 3    30
# dtype: int64

# %%
contest_result = pd.Series(data=[10,5,100],index=["Atil","James","Lars"])
contest_result2 = pd.Series(data=[20,9,10],index=["Atil","James","Lars"])

# %%
contest_result + contest_result2
# Out:
# Atil      30
# James     14
# Lars     110
# dtype: int64
