# %%
import pandas as pd
import numpy as np

# %%
data = np.random.randn(4,3)

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#           0         1         2
# 0  0.431152  0.416453  1.184432
# 1 -0.493698  1.061889  0.379888
# 2  0.827030 -0.177320  1.496683
# 3 -0.159509 -1.057945 -1.931546

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
new_df = pd.DataFrame(data,index=["atil","zeynep","atlas", "mehmet"], columns = ["salary","age","seniority"])

# %%
new_df
# Out:
#           salary       age  seniority
# atil    0.431152  0.416453   1.184432
# zeynep -0.493698  1.061889   0.379888
# atlas   0.827030 -0.177320   1.496683
# mehmet -0.159509 -1.057945  -1.931546

# %%
new_df[["age"]]
# Out:
#              age
# atil    0.416453
# zeynep  1.061889
# atlas  -0.177320
# mehmet -1.057945

# %%
new_df.loc["atil"]
# Out:
# salary       0.431152
# age          0.416453
# seniority    1.184432
# Name: atil, dtype: float64

# %%
new_df.iloc[0]
# Out:
# salary       0.431152
# age          0.416453
# seniority    1.184432
# Name: atil, dtype: float64

# %%
new_df["extra"] = 10

# %%
new_df
# Out:
#           salary       age  seniority  extra
# atil    0.431152  0.416453   1.184432     10
# zeynep -0.493698  1.061889   0.379888     10
# atlas   0.827030 -0.177320   1.496683     10
# mehmet -0.159509 -1.057945  -1.931546     10

# %%
new_df.drop("extra",axis=1)
# Out:
#           salary       age  seniority
# atil    0.431152  0.416453   1.184432
# zeynep -0.493698  1.061889   0.379888
# atlas   0.827030 -0.177320   1.496683
# mehmet -0.159509 -1.057945  -1.931546
